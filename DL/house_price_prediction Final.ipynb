# %% [markdown]
# ### Deep Learning approaches to build a predictive model

# %%
#import necessary libraries
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping

# %%
#load the data
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data'
col_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
                'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV' ]
house_df =  pd.read_csv(url, sep= '\s+', names=col_names )
house_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0  \
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
'''====== Data Exploration and Preprocessing ======'''

#shape of dataframe
house_df.shape
# Out:
# (506, 14)

# %%
#check there are any NAN values
house_df.isnull().values.any()
# Out:
# False

# %%
'''=== show the statistics analysis of each attributes ==='''

#descriptive statistics 
house_df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000  \
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000  \
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
'''=== Show the linear relationship between features  and price (MEDV). Thus, it provides that how the scattered 
      they are and which features has more impact in prediction of house price. ==='''

# visiualize all variables  with price(MEDV)
from scipy import stats
#creates figure
plt.figure(figsize=(18, 18))

for i, col in enumerate(house_df.columns[0:13]): #iterates over all columns except for price column (last one)
    plt.subplot(5, 3, i+1) # each row three figure
    x = house_df[col] #x-axis
    y = house_df['MEDV'] #y-axis
    plt.plot(x, y, 'o')
    
    # Create regression line
    plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1)) (np.unique(x)), color='red')
    plt.xlabel(col) # x-label
    plt.ylabel('prices') # y-label

# %%
# separate the training and target variable
feature = house_df.iloc[:,0:13] #  training variables
target = house_df.iloc[:,13] # target varible
print(feature.head())
print('\n',target.head())
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0  \
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33
#
#  0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: MEDV, dtype: float64

# %%
'''=== Noramlization the features. Since it is seen that features have different ranges, it is best practice to
normalize/standarize the feature before using them in the model ==='''

#feature normalization
normalized_feature =  keras.utils.normalize(feature.values)
print(normalized_feature)
# Out:
# [[1.26388341e-05 3.59966795e-02 4.61957387e-03 ... 3.05971776e-02
#   7.93726783e-01 9.95908132e-03]
#  [5.78529889e-05 0.00000000e+00 1.49769546e-02 ... 3.77071843e-02
#   8.40785474e-01 1.93620036e-02]
#  [5.85729947e-05 0.00000000e+00 1.51744622e-02 ... 3.82044450e-02
#   8.43137761e-01 8.64965806e-03]
#  ...
#  [1.23765824e-04 0.00000000e+00 2.43009593e-02 ... 4.27762066e-02
#   8.08470305e-01 1.14884669e-02]
#  [2.24644719e-04 0.00000000e+00 2.44548909e-02 ... 4.30471676e-02
#   8.06519433e-01 1.32831260e-02]
#  [9.69214289e-05 0.00000000e+00 2.43887924e-02 ... 4.29308164e-02
#   8.11392431e-01 1.61092778e-02]]

# %%
'''==== Multi-Layer Perception architecture is used for prediction of house price ===='''

# shuffle and split data into train (~80%) and test (~20%)
X_train, X_test, y_train, y_test = train_test_split(normalized_feature, target.values, 
                                                    test_size=0.2, random_state=42) 
print('training data shape: ',X_train.shape)
print('testing data shape: ',X_test.shape)
# Out:
# training data shape:  (404, 13)
# testing data shape:  (102, 13)

# %%
'''===== Build MLP Network ====='''

#get number of columns in training data
n_cols = X_train.shape[1]

# builds model
model = keras.Sequential()

model.add(keras.layers.Dense(150, activation=tf.nn.relu, 
                       input_shape=(n_cols,)))
model.add(keras.layers.Dense(150, activation=tf.nn.relu))
model.add(keras.layers.Dense(150, activation=tf.nn.relu))
model.add(keras.layers.Dense(150, activation=tf.nn.relu))
model.add(keras.layers.Dense(150, activation=tf.nn.relu))
model.add(keras.layers.Dense(1))

#compile model
model.compile(loss='mse', optimizer='adam', metrics=['mae']) # use metric as mean absolute error

#inspect the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 150)               2100
#
#  dense_1 (Dense)             (None, 150)               22650
#
#  dense_2 (Dense)             (None, 150)               22650
#
#  dense_3 (Dense)             (None, 150)               22650
#
#  dense_4 (Dense)             (None, 150)               22650
#
#  dense_5 (Dense)             (None, 1)                 151
#
# =================================================================
# Total params: 92,851
# Trainable params: 92,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
#train model and perform validation test

early_stop = EarlyStopping(monitor='val_loss', patience=15) # stops training when it doesn't show improvemnet.

history = model.fit(X_train, y_train, epochs=300, 
          validation_split=0.2, verbose=1, callbacks=[early_stop])
# Out:
# Epoch 1/300
# 11/11 [==============================] - 1s 24ms/step - loss: 603.5733 - mae: 22.6419 - val_loss: 505.7944 - val_mae: 20.8811
# Epoch 2/300
# 11/11 [==============================] - 0s 6ms/step - loss: 467.4755 - mae: 19.3204 - val_loss: 203.5879 - val_mae: 11.7843
# Epoch 3/300
# 11/11 [==============================] - 0s 6ms/step - loss: 147.8239 - mae: 10.0079 - val_loss: 113.3316 - val_mae: 9.3458
# Epoch 4/300
# 11/11 [==============================] - 0s 6ms/step - loss: 100.9959 - mae: 7.6676 - val_loss: 77.8077 - val_mae: 5.8802
# Epoch 5/300
# 11/11 [==============================] - 0s 6ms/step - loss: 91.6051 - mae: 6.7514 - val_loss: 68.8766 - val_mae: 6.7298
# Epoch 6/300
# 11/11 [==============================] - 0s 6ms/step - loss: 82.0804 - mae: 6.9492 - val_loss: 58.9817 - val_mae: 5.3982
# Epoch 7/300
# 11/11 [==============================] - 0s 6ms/step - loss: 77.8027 - mae: 6.9344 - val_loss: 57.4019 - val_mae: 5.1881
# Epoch 8/300
# 11/11 [==============================] - 0s 6ms/step - loss: 73.4359 - mae: 5.9170 - val_loss: 57.7795 - val_mae: 5.5229
# Epoch 9/300
# 11/11 [==============================] - 0s 6ms/step - loss: 68.3960 - mae: 6.2357 - val_loss: 56.9763 - val_mae: 5.2798
# Epoch 10/300
# 11/11 [==============================] - 0s 6ms/step - loss: 66.8129 - mae: 5.9247 - val_loss: 57.4638 - val_mae: 5.1336
# Epoch 11/300
# 11/11 [==============================] - 0s 6ms/step - loss: 66.2622 - mae: 5.7612 - val_loss: 61.7000 - val_mae: 5.9019
# Epoch 12/300
# 11/11 [==============================] - 0s 6ms/step - loss: 71.2285 - mae: 6.6439 - val_loss: 62.2115 - val_mae: 5.0059
# Epoch 13/300
# 11/11 [==============================] - 0s 6ms/step - loss: 68.8190 - mae: 5.7152 - val_loss: 64.0825 - val_mae: 6.0804
# Epoch 14/300
# 11/11 [==============================] - 0s 6ms/step - loss: 71.6696 - mae: 6.6362 - val_loss: 59.2844 - val_mae: 4.8400
# Epoch 15/300
# 11/11 [==============================] - 0s 6ms/step - loss: 67.5198 - mae: 5.5603 - val_loss: 67.1953 - val_mae: 6.3699
# Epoch 16/300
# 11/11 [==============================] - 0s 6ms/step - loss: 70.1960 - mae: 6.4850 - val_loss: 58.4457 - val_mae: 4.9216
# Epoch 17/300
# 11/11 [==============================] - 0s 6ms/step - loss: 63.8209 - mae: 5.6159 - val_loss: 59.3377 - val_mae: 5.6728
# Epoch 18/300
# 11/11 [==============================] - 0s 6ms/step - loss: 63.4314 - mae: 5.7665 - val_loss: 56.1369 - val_mae: 5.1052
# Epoch 19/300
# 11/11 [==============================] - 0s 7ms/step - loss: 64.0455 - mae: 5.5712 - val_loss: 60.6030 - val_mae: 5.8081
# Epoch 20/300
# 11/11 [==============================] - 0s 6ms/step - loss: 65.8743 - mae: 5.9613 - val_loss: 55.8510 - val_mae: 5.2421
# Epoch 21/300
# 11/11 [==============================] - 0s 6ms/step - loss: 63.6557 - mae: 5.9770 - val_loss: 56.0013 - val_mae: 4.9814
# Epoch 22/300
# 11/11 [==============================] - 0s 6ms/step - loss: 63.4273 - mae: 5.6307 - val_loss: 56.3472 - val_mae: 5.3344
# Epoch 23/300
# 11/11 [==============================] - 0s 6ms/step - loss: 64.9794 - mae: 5.6797 - val_loss: 58.0032 - val_mae: 5.5509
# Epoch 24/300
# 11/11 [==============================] - 0s 6ms/step - loss: 62.3869 - mae: 5.7909 - val_loss: 55.1265 - val_mae: 5.0550
# Epoch 25/300
# 11/11 [==============================] - 0s 6ms/step - loss: 61.1568 - mae: 5.7050 - val_loss: 55.1169 - val_mae: 5.1669
# Epoch 26/300
# 11/11 [==============================] - 0s 6ms/step - loss: 61.7799 - mae: 5.5506 - val_loss: 56.9711 - val_mae: 5.4980
# Epoch 27/300
# 11/11 [==============================] - 0s 6ms/step - loss: 61.7357 - mae: 5.8511 - val_loss: 54.3481 - val_mae: 4.8699
# Epoch 28/300
# 11/11 [==============================] - 0s 6ms/step - loss: 60.9316 - mae: 5.6618 - val_loss: 55.4343 - val_mae: 5.3179
# Epoch 29/300
# 11/11 [==============================] - 0s 6ms/step - loss: 60.8322 - mae: 5.5771 - val_loss: 56.8953 - val_mae: 5.4702
# Epoch 30/300
# 11/11 [==============================] - 0s 6ms/step - loss: 64.4651 - mae: 6.0312 - val_loss: 56.2741 - val_mae: 4.8681
# Epoch 31/300
# 11/11 [==============================] - 0s 6ms/step - loss: 60.7937 - mae: 5.4735 - val_loss: 57.1994 - val_mae: 5.5206
# Epoch 32/300
# 11/11 [==============================] - 0s 6ms/step - loss: 61.3191 - mae: 5.6935 - val_loss: 53.4518 - val_mae: 4.9777
# Epoch 33/300
# 11/11 [==============================] - 0s 6ms/step - loss: 59.0853 - mae: 5.5815 - val_loss: 54.9531 - val_mae: 5.3113
# Epoch 34/300
# 11/11 [==============================] - 0s 6ms/step - loss: 59.6760 - mae: 5.6080 - val_loss: 53.5308 - val_mae: 5.2182
# Epoch 35/300
# 11/11 [==============================] - 0s 6ms/step - loss: 63.9040 - mae: 6.1146 - val_loss: 56.4748 - val_mae: 4.7209
# Epoch 36/300
# 11/11 [==============================] - 0s 6ms/step - loss: 63.4234 - mae: 5.5993 - val_loss: 56.4752 - val_mae: 5.4831
# Epoch 37/300
# 11/11 [==============================] - 0s 6ms/step - loss: 58.5256 - mae: 5.4024 - val_loss: 53.9267 - val_mae: 5.2320
# Epoch 38/300
# 11/11 [==============================] - 0s 6ms/step - loss: 58.5555 - mae: 5.7093 - val_loss: 52.9445 - val_mae: 4.9090
# Epoch 39/300
# 11/11 [==============================] - 0s 6ms/step - loss: 57.3464 - mae: 5.4247 - val_loss: 54.0274 - val_mae: 5.2507
# Epoch 40/300
# 11/11 [==============================] - 0s 6ms/step - loss: 56.5090 - mae: 5.5235 - val_loss: 52.3078 - val_mae: 4.8332
# Epoch 41/300
# 11/11 [==============================] - 0s 6ms/step - loss: 56.9139 - mae: 5.2422 - val_loss: 57.8870 - val_mae: 5.6291
# Epoch 42/300
# 11/11 [==============================] - 0s 6ms/step - loss: 58.2837 - mae: 5.4964 - val_loss: 51.3128 - val_mae: 4.7091
# Epoch 43/300
# 11/11 [==============================] - 0s 6ms/step - loss: 56.8847 - mae: 5.5210 - val_loss: 50.7892 - val_mae: 4.8741
# Epoch 44/300
# 11/11 [==============================] - 0s 6ms/step - loss: 55.6093 - mae: 5.2608 - val_loss: 52.7764 - val_mae: 5.2408
# Epoch 45/300
# 11/11 [==============================] - 0s 6ms/step - loss: 54.8777 - mae: 5.2501 - val_loss: 51.2504 - val_mae: 4.9747
# Epoch 46/300
# 11/11 [==============================] - 0s 6ms/step - loss: 55.2702 - mae: 5.5030 - val_loss: 53.8615 - val_mae: 4.7014
# Epoch 47/300
# 11/11 [==============================] - 0s 6ms/step - loss: 57.5668 - mae: 5.1880 - val_loss: 52.0701 - val_mae: 5.2320
# Epoch 48/300
# 11/11 [==============================] - 0s 6ms/step - loss: 55.1910 - mae: 5.0989 - val_loss: 53.2670 - val_mae: 5.3242
# Epoch 49/300
# 11/11 [==============================] - 0s 6ms/step - loss: 53.8009 - mae: 5.5113 - val_loss: 53.2257 - val_mae: 4.5631
# Epoch 50/300
# 11/11 [==============================] - 0s 6ms/step - loss: 56.7912 - mae: 5.1460 - val_loss: 87.9252 - val_mae: 7.8529
# Epoch 51/300
# 11/11 [==============================] - 0s 6ms/step - loss: 71.3655 - mae: 6.2092 - val_loss: 50.2005 - val_mae: 4.3089
# Epoch 52/300
# 11/11 [==============================] - 0s 6ms/step - loss: 56.0728 - mae: 5.7286 - val_loss: 48.4969 - val_mae: 4.3683
# Epoch 53/300
# 11/11 [==============================] - 0s 6ms/step - loss: 57.0100 - mae: 5.0370 - val_loss: 51.3601 - val_mae: 5.2747
# Epoch 54/300
# 11/11 [==============================] - 0s 6ms/step - loss: 51.6789 - mae: 4.9993 - val_loss: 47.5392 - val_mae: 4.7427
# Epoch 55/300
# 11/11 [==============================] - 0s 6ms/step - loss: 49.9889 - mae: 4.8893 - val_loss: 50.1548 - val_mae: 5.0907
# Epoch 56/300
# 11/11 [==============================] - 0s 7ms/step - loss: 52.6949 - mae: 5.2213 - val_loss: 46.7243 - val_mae: 4.3823
# Epoch 57/300
# 11/11 [==============================] - 0s 6ms/step - loss: 52.2046 - mae: 5.1950 - val_loss: 47.4816 - val_mae: 4.3571
# Epoch 58/300
# 11/11 [==============================] - 0s 6ms/step - loss: 49.9925 - mae: 4.8621 - val_loss: 46.8891 - val_mae: 4.8491
# Epoch 59/300
# 11/11 [==============================] - 0s 5ms/step - loss: 48.9981 - mae: 4.7368 - val_loss: 49.3213 - val_mae: 5.1203
# Epoch 60/300
# 11/11 [==============================] - 0s 6ms/step - loss: 47.0468 - mae: 4.8650 - val_loss: 44.3036 - val_mae: 4.5719
# Epoch 61/300
# 11/11 [==============================] - 0s 6ms/step - loss: 46.1323 - mae: 4.8719 - val_loss: 47.5767 - val_mae: 4.2889
# Epoch 62/300
# 11/11 [==============================] - 0s 6ms/step - loss: 48.7084 - mae: 4.9668 - val_loss: 44.2211 - val_mae: 4.6446
# Epoch 63/300
# 11/11 [==============================] - 0s 7ms/step - loss: 43.4628 - mae: 4.6541 - val_loss: 42.7398 - val_mae: 4.2393
# Epoch 64/300
# 11/11 [==============================] - 0s 6ms/step - loss: 43.8529 - mae: 4.6128 - val_loss: 41.3121 - val_mae: 4.0700
# Epoch 65/300
# 11/11 [==============================] - 0s 6ms/step - loss: 52.2955 - mae: 4.8817 - val_loss: 43.0131 - val_mae: 4.8271
# Epoch 66/300
# 11/11 [==============================] - 0s 6ms/step - loss: 45.3571 - mae: 4.4716 - val_loss: 52.1275 - val_mae: 5.6014
# Epoch 67/300
# 11/11 [==============================] - 0s 6ms/step - loss: 45.4266 - mae: 4.8322 - val_loss: 40.1638 - val_mae: 4.0994
# Epoch 68/300
# 11/11 [==============================] - 0s 6ms/step - loss: 39.5229 - mae: 4.5306 - val_loss: 40.3257 - val_mae: 3.9147
# Epoch 69/300
# 11/11 [==============================] - 0s 5ms/step - loss: 45.1373 - mae: 4.6660 - val_loss: 38.4713 - val_mae: 4.3031
# Epoch 70/300
# 11/11 [==============================] - 0s 6ms/step - loss: 41.4227 - mae: 4.4643 - val_loss: 44.9331 - val_mae: 5.0940
# Epoch 71/300
# 11/11 [==============================] - 0s 6ms/step - loss: 42.6784 - mae: 4.6115 - val_loss: 37.3403 - val_mae: 4.2573
# Epoch 72/300
# 11/11 [==============================] - 0s 6ms/step - loss: 35.8253 - mae: 4.2742 - val_loss: 46.3018 - val_mae: 5.2265
# Epoch 73/300
# 11/11 [==============================] - 0s 6ms/step - loss: 42.2292 - mae: 4.8871 - val_loss: 37.2871 - val_mae: 3.8394
# Epoch 74/300
# 11/11 [==============================] - 0s 6ms/step - loss: 37.7059 - mae: 4.6554 - val_loss: 35.5969 - val_mae: 3.7045
# Epoch 75/300
# 11/11 [==============================] - 0s 6ms/step - loss: 33.0558 - mae: 4.1471 - val_loss: 33.5380 - val_mae: 3.6786
# Epoch 76/300
# 11/11 [==============================] - 0s 6ms/step - loss: 31.8694 - mae: 4.0961 - val_loss: 34.6361 - val_mae: 3.9530
# Epoch 77/300
# 11/11 [==============================] - 0s 6ms/step - loss: 31.9090 - mae: 4.0011 - val_loss: 36.1393 - val_mae: 4.2549
# Epoch 78/300
# 11/11 [==============================] - 0s 6ms/step - loss: 29.1668 - mae: 3.9646 - val_loss: 31.5119 - val_mae: 3.6537
# Epoch 79/300
# 11/11 [==============================] - 0s 6ms/step - loss: 27.8025 - mae: 3.9154 - val_loss: 34.6197 - val_mae: 4.0157
# Epoch 80/300
# 11/11 [==============================] - 0s 6ms/step - loss: 29.8145 - mae: 4.0872 - val_loss: 30.9149 - val_mae: 3.5477
# Epoch 81/300
# 11/11 [==============================] - 0s 6ms/step - loss: 26.2937 - mae: 3.8228 - val_loss: 29.5498 - val_mae: 3.4943
# Epoch 82/300
# 11/11 [==============================] - 0s 7ms/step - loss: 25.1661 - mae: 3.6848 - val_loss: 29.3656 - val_mae: 3.5067
# Epoch 83/300
# 11/11 [==============================] - 0s 7ms/step - loss: 25.4047 - mae: 3.6765 - val_loss: 43.5504 - val_mae: 5.1234
# Epoch 84/300
# 11/11 [==============================] - 0s 6ms/step - loss: 30.2276 - mae: 4.2974 - val_loss: 34.2626 - val_mae: 4.0370
# Epoch 85/300
# 11/11 [==============================] - 0s 6ms/step - loss: 24.9746 - mae: 3.7468 - val_loss: 32.0699 - val_mae: 3.9206
# Epoch 86/300
# 11/11 [==============================] - 0s 6ms/step - loss: 23.9007 - mae: 3.7061 - val_loss: 29.2024 - val_mae: 3.5702
# Epoch 87/300
# 11/11 [==============================] - 0s 8ms/step - loss: 22.4347 - mae: 3.5830 - val_loss: 27.2432 - val_mae: 3.4864
# Epoch 88/300
# 11/11 [==============================] - 0s 7ms/step - loss: 21.9324 - mae: 3.5933 - val_loss: 28.8853 - val_mae: 3.5783
# Epoch 89/300
# 11/11 [==============================] - 0s 6ms/step - loss: 22.8488 - mae: 3.6927 - val_loss: 27.0776 - val_mae: 3.4421
# Epoch 90/300
# 11/11 [==============================] - 0s 6ms/step - loss: 21.3884 - mae: 3.4841 - val_loss: 26.5308 - val_mae: 3.3461
# Epoch 91/300
# 11/11 [==============================] - 0s 7ms/step - loss: 22.2400 - mae: 3.5126 - val_loss: 29.7656 - val_mae: 3.7299
# Epoch 92/300
# 11/11 [==============================] - 0s 6ms/step - loss: 21.1447 - mae: 3.5011 - val_loss: 26.5937 - val_mae: 3.3425
# Epoch 93/300
# 11/11 [==============================] - 0s 7ms/step - loss: 20.2432 - mae: 3.4394 - val_loss: 28.0148 - val_mae: 3.4566
# Epoch 94/300
# 11/11 [==============================] - 0s 7ms/step - loss: 23.8938 - mae: 3.6081 - val_loss: 28.5199 - val_mae: 3.4755
# Epoch 95/300
# 11/11 [==============================] - 0s 6ms/step - loss: 20.7424 - mae: 3.5138 - val_loss: 30.5704 - val_mae: 3.8506
# Epoch 96/300
# 11/11 [==============================] - 0s 7ms/step - loss: 27.8019 - mae: 3.9689 - val_loss: 61.0703 - val_mae: 6.1716
# Epoch 97/300
# 11/11 [==============================] - 0s 6ms/step - loss: 29.6115 - mae: 4.0457 - val_loss: 37.5392 - val_mae: 4.6609
# Epoch 98/300
# 11/11 [==============================] - 0s 6ms/step - loss: 23.0352 - mae: 3.5748 - val_loss: 23.7526 - val_mae: 3.1873
# Epoch 99/300
# 11/11 [==============================] - 0s 6ms/step - loss: 19.3195 - mae: 3.3412 - val_loss: 38.5068 - val_mae: 4.8118
# Epoch 100/300
# 11/11 [==============================] - 0s 8ms/step - loss: 20.9768 - mae: 3.4760 - val_loss: 23.3290 - val_mae: 3.2427
# Epoch 101/300
# 11/11 [==============================] - 0s 9ms/step - loss: 18.8011 - mae: 3.2218 - val_loss: 37.6618 - val_mae: 4.6458
# Epoch 102/300
# 11/11 [==============================] - 0s 7ms/step - loss: 22.6538 - mae: 3.6195 - val_loss: 26.1584 - val_mae: 3.4936
# Epoch 103/300
# 11/11 [==============================] - 0s 6ms/step - loss: 19.4798 - mae: 3.3639 - val_loss: 22.4348 - val_mae: 3.1542
# Epoch 104/300
# 11/11 [==============================] - 0s 8ms/step - loss: 19.2809 - mae: 3.2073 - val_loss: 24.8024 - val_mae: 3.2359
# Epoch 105/300
# 11/11 [==============================] - 0s 7ms/step - loss: 18.4650 - mae: 3.2355 - val_loss: 23.4802 - val_mae: 3.1318
# Epoch 106/300
# 11/11 [==============================] - 0s 6ms/step - loss: 17.8455 - mae: 3.2170 - val_loss: 23.5698 - val_mae: 3.2728
# Epoch 107/300
# 11/11 [==============================] - 0s 6ms/step - loss: 17.1516 - mae: 3.1385 - val_loss: 59.3788 - val_mae: 6.1603
# Epoch 108/300
# 11/11 [==============================] - 0s 6ms/step - loss: 34.3287 - mae: 4.1487 - val_loss: 43.2994 - val_mae: 5.2067
# Epoch 109/300
# 11/11 [==============================] - 0s 6ms/step - loss: 20.5488 - mae: 3.3761 - val_loss: 27.3550 - val_mae: 3.6925
# Epoch 110/300
# 11/11 [==============================] - 0s 6ms/step - loss: 37.0544 - mae: 4.6219 - val_loss: 23.3617 - val_mae: 3.4124
# Epoch 111/300
# 11/11 [==============================] - 0s 6ms/step - loss: 19.4853 - mae: 3.4133 - val_loss: 23.4694 - val_mae: 3.3094
# Epoch 112/300
# 11/11 [==============================] - 0s 7ms/step - loss: 17.5266 - mae: 3.1895 - val_loss: 23.3752 - val_mae: 3.2926
# Epoch 113/300
# 11/11 [==============================] - 0s 7ms/step - loss: 18.2737 - mae: 3.2004 - val_loss: 34.6984 - val_mae: 4.5346
# Epoch 114/300
# 11/11 [==============================] - 0s 7ms/step - loss: 23.5492 - mae: 3.6111 - val_loss: 28.1242 - val_mae: 3.7625
# Epoch 115/300
# 11/11 [==============================] - 0s 7ms/step - loss: 18.8310 - mae: 3.2518 - val_loss: 26.0974 - val_mae: 3.5493
# Epoch 116/300
# 11/11 [==============================] - 0s 7ms/step - loss: 22.3915 - mae: 3.4540 - val_loss: 24.5747 - val_mae: 3.2636
# Epoch 117/300
# 11/11 [==============================] - 0s 6ms/step - loss: 17.9245 - mae: 3.1983 - val_loss: 27.0230 - val_mae: 3.6051
# Epoch 118/300
# 11/11 [==============================] - 0s 6ms/step - loss: 19.8234 - mae: 3.3498 - val_loss: 22.9733 - val_mae: 3.2476

# %%
# show the graph of model loss in trainig and validation 

plt.figure(figsize=(15,8))
plt.xlabel('Epoch')
plt.ylabel('Mean Square Error')
plt.plot(history.epoch, history.history['loss'],
           label='Train Loss')
plt.plot(history.epoch, history.history['val_loss'],
           label = 'Val loss')
plt.title('Model loss')
plt.legend()

# %%
#check the model performace in test dataset
score = model.evaluate(X_test, y_test, verbose=1)
print('loss value: ', score[0])
print('Mean absolute error: ', score[1])
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 18.9659 - mae: 3.2074
# loss value:  18.965877532958984
# Mean absolute error:  3.207369327545166

# %%
'''=== predict the house price ==='''

# predict house price using the test data 
test_predictions = model.predict(X_test).flatten()
print(test_predictions)
# Out:
# 4/4 [==============================] - 0s 3ms/step
# [27.909279  39.197765  19.510557  25.398352  19.264597  20.207712
#  17.86031   14.703606  25.438738  20.073786  20.073381  18.272516
#   6.934608  19.764576  21.360857  26.465471  20.135971  12.16287
#  43.45252   17.891504  26.710897  26.357534  14.4629    22.818136
#  20.101728  17.506186  22.409103  14.088444  19.718378  19.855192
#  21.358229  24.938013  20.51727   30.551455  16.387041  15.377739
#  34.964592  23.432577  19.858515  22.376726  16.112053  33.791836
#  46.057472  19.291914  24.967075  19.239061  16.597189  23.2947
#  20.1084    36.590717  20.862825  37.83552   17.670137  29.453651
#  46.05917   27.045542  20.395597  36.596596  23.397106  16.4275
#  22.132925  33.27265   37.16064   16.78894   26.474005  16.928797
#  19.130568  24.962551  33.049797  14.387751  20.545496  33.49654
#  13.970074  23.571743  21.33372   10.484445  21.344442  43.362682
#  14.905045  15.856251  22.199312  13.652628  22.305683  13.607077
#  22.405563  29.881052  20.012106  26.63373   25.352325  19.265173
#  23.185564  10.280841  20.401154  18.398272  33.717224  21.440115
#  30.128664   7.8368793 14.048037  13.008849  21.307264  22.664032 ]

# %%
# show the true value and predicted value in dataframe
true_predicted = pd.DataFrame(list(zip(y_test, test_predictions)), 
                    columns=['True Value','Predicted Value'])
true_predicted.head(10)
# Out:
#    True Value  Predicted Value
# 0        23.6        27.909279
# 1        32.4        39.197765
# 2        13.6        19.510557
# 3        22.8        25.398352
# 4        16.1        19.264597
# 5        20.0        20.207712
# 6        17.8        17.860310
# 7        14.0        14.703606
# 8        19.6        25.438738
# 9        16.8        20.073786

# %%
#visiulize the true value with predicted value (using line graph)
x = test_predictions
y = y_test
plt.figure(figsize=(30,10))
plt.plot(x, label='predicted value')
plt.plot(y, label='true value')
plt.title('Evaluation Result')
plt.legend()
plt.show()

# %%
'''=== Visualize the model evaluation skill ==='''


# visualize the prediction uisng diagonal line
y = test_predictions #y-axis
x = y_test #x-axis
fig, ax = plt.subplots(figsize=(10,6)) # create figure
ax.scatter(x,y) #scatter plots for x,y
ax.set(xlim=(0,55), ylim=(0, 55)) #set limit
ax.plot(ax.get_xlim(), ax.get_ylim(), color ='red') # draw 45 degree diagonal in figure
plt.xlabel('True Values')
plt.ylabel('Predicted values')
plt.title('Evaluation Result')
plt.show()

# %% [markdown]
#          ======= Remove outliers from the data set ========
#   Tried to see the model perfomance after removing the outliers, the perfomance doesn't
#   show much improvemnt. This might be less data size after remoing the outliers.

# %%
#calcualtes quartiles and interquaterlies
Q1 = house_df.quantile(0.25)
Q3 = house_df.quantile(0.75)
IQR = Q3 - Q1

# %%
house_data = house_df.iloc[:,0:14]
house_data.shape
# Out:
# (506, 14)

# %%
#data after outliers remvoing
clean_data = house_df[~((house_data < (Q1 - 1.5 * IQR)) |(house_data > (Q3 + 1.5 * IQR))).any(axis=1)]
clean_data.shape
# Out:
# (268, 14)

# %%
feature = clean_data.iloc[:,0:13] #  training variables
target = clean_data.iloc[:,13] # target varible
print(feature.head())
print('\n',target.head())
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0  \
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33
#
#  0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: MEDV, dtype: float64

# %%
#feature normalization
normalized_feature =  keras.utils.normalize(feature.values)
print(normalized_feature)
# Out:
# [[1.26388341e-05 3.59966795e-02 4.61957387e-03 ... 3.05971776e-02
#   7.93726783e-01 9.95908132e-03]
#  [5.78529889e-05 0.00000000e+00 1.49769546e-02 ... 3.77071843e-02
#   8.40785474e-01 1.93620036e-02]
#  [5.85729947e-05 0.00000000e+00 1.51744622e-02 ... 3.82044450e-02
#   8.43137761e-01 8.64965806e-03]
#  ...
#  [1.23765824e-04 0.00000000e+00 2.43009593e-02 ... 4.27762066e-02
#   8.08470305e-01 1.14884669e-02]
#  [2.24644719e-04 0.00000000e+00 2.44548909e-02 ... 4.30471676e-02
#   8.06519433e-01 1.32831260e-02]
#  [9.69214289e-05 0.00000000e+00 2.43887924e-02 ... 4.29308164e-02
#   8.11392431e-01 1.61092778e-02]]

# %%
# shuffle and split data into train (~80%) and test (~20%)
X_train, X_test, y_train, y_test = train_test_split(normalized_feature, target.values, test_size=0.2, random_state=42) 
print('training data shape: ',X_train.shape)
print('testing data shape: ',X_test.shape)
# Out:
# training data shape:  (214, 13)
# testing data shape:  (54, 13)

# %%
#get number of columns in training data
n_cols = X_train.shape[1]

# builds model
model = keras.Sequential()

model.add(keras.layers.Dense(150, activation=tf.nn.relu, 
                       input_shape=(n_cols,)))
model.add(keras.layers.Dense(150, activation=tf.nn.relu))
model.add(keras.layers.Dense(150, activation=tf.nn.relu))
model.add(keras.layers.Dense(150, activation=tf.nn.relu))
model.add(keras.layers.Dense(150, activation=tf.nn.relu))
model.add(keras.layers.Dense(1))

#compile model
model.compile(loss='mse', optimizer='adam', metrics=['mae']) # use metric as mean absolute error

#inspect the model
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 150)               2100
#
#  dense_7 (Dense)             (None, 150)               22650
#
#  dense_8 (Dense)             (None, 150)               22650
#
#  dense_9 (Dense)             (None, 150)               22650
#
#  dense_10 (Dense)            (None, 150)               22650
#
#  dense_11 (Dense)            (None, 1)                 151
#
# =================================================================
# Total params: 92,851
# Trainable params: 92,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
#train model
early_stop = EarlyStopping(monitor='val_loss', patience=20) # stops training when it doesn't show improvemnet.

history = model.fit(X_train, y_train, epochs=300, 
          validation_split=0.2, verbose=1, callbacks=[early_stop])
# Out:
# Epoch 1/300
# 6/6 [==============================] - 1s 36ms/step - loss: 485.6162 - mae: 21.4533 - val_loss: 434.2736 - val_mae: 20.4839
# Epoch 2/300
# 6/6 [==============================] - 0s 10ms/step - loss: 456.9400 - mae: 20.7728 - val_loss: 381.3923 - val_mae: 19.1506
# Epoch 3/300
# 6/6 [==============================] - 0s 10ms/step - loss: 373.5603 - mae: 18.6544 - val_loss: 240.2772 - val_mae: 15.0236
# Epoch 4/300
# 6/6 [==============================] - 0s 9ms/step - loss: 182.9552 - mae: 12.2763 - val_loss: 23.8373 - val_mae: 3.7781
# Epoch 5/300
# 6/6 [==============================] - 0s 10ms/step - loss: 48.5347 - mae: 5.5945 - val_loss: 81.0181 - val_mae: 8.2719
# Epoch 6/300
# 6/6 [==============================] - 0s 10ms/step - loss: 47.8689 - mae: 5.6632 - val_loss: 16.8282 - val_mae: 3.0607
# Epoch 7/300
# 6/6 [==============================] - 0s 11ms/step - loss: 35.8325 - mae: 4.5768 - val_loss: 25.8508 - val_mae: 3.9960
# Epoch 8/300
# 6/6 [==============================] - 0s 10ms/step - loss: 32.1642 - mae: 4.3649 - val_loss: 14.8294 - val_mae: 3.0311
# Epoch 9/300
# 6/6 [==============================] - 0s 10ms/step - loss: 25.8612 - mae: 3.8839 - val_loss: 21.2555 - val_mae: 3.7891
# Epoch 10/300
# 6/6 [==============================] - 0s 10ms/step - loss: 24.0392 - mae: 3.7559 - val_loss: 14.5911 - val_mae: 2.9500
# Epoch 11/300
# 6/6 [==============================] - 0s 10ms/step - loss: 23.3676 - mae: 3.5858 - val_loss: 14.7627 - val_mae: 2.9420
# Epoch 12/300
# 6/6 [==============================] - 0s 10ms/step - loss: 22.7508 - mae: 3.5510 - val_loss: 15.5121 - val_mae: 3.1498
# Epoch 13/300
# 6/6 [==============================] - 0s 9ms/step - loss: 21.8233 - mae: 3.4979 - val_loss: 14.9635 - val_mae: 3.0436
# Epoch 14/300
# 6/6 [==============================] - 0s 9ms/step - loss: 21.3078 - mae: 3.4696 - val_loss: 15.7057 - val_mae: 3.1700
# Epoch 15/300
# 6/6 [==============================] - 0s 11ms/step - loss: 21.2381 - mae: 3.4838 - val_loss: 15.3666 - val_mae: 3.1081
# Epoch 16/300
# 6/6 [==============================] - 0s 10ms/step - loss: 20.7667 - mae: 3.4375 - val_loss: 15.3732 - val_mae: 3.1008
# Epoch 17/300
# 6/6 [==============================] - 0s 9ms/step - loss: 20.4866 - mae: 3.4132 - val_loss: 15.3264 - val_mae: 3.0774
# Epoch 18/300
# 6/6 [==============================] - 0s 10ms/step - loss: 20.4213 - mae: 3.4229 - val_loss: 15.4048 - val_mae: 3.0763
# Epoch 19/300
# 6/6 [==============================] - 0s 9ms/step - loss: 20.2123 - mae: 3.3790 - val_loss: 15.3646 - val_mae: 3.0111
# Epoch 20/300
# 6/6 [==============================] - 0s 10ms/step - loss: 20.0368 - mae: 3.3717 - val_loss: 15.9239 - val_mae: 3.1601
# Epoch 21/300
# 6/6 [==============================] - 0s 10ms/step - loss: 20.0186 - mae: 3.4386 - val_loss: 16.2497 - val_mae: 3.2059
# Epoch 22/300
# 6/6 [==============================] - 0s 9ms/step - loss: 19.4136 - mae: 3.3756 - val_loss: 15.7310 - val_mae: 3.0876
# Epoch 23/300
# 6/6 [==============================] - 0s 11ms/step - loss: 19.3912 - mae: 3.3275 - val_loss: 16.1069 - val_mae: 3.1716
# Epoch 24/300
# 6/6 [==============================] - 0s 10ms/step - loss: 19.1615 - mae: 3.3527 - val_loss: 16.4088 - val_mae: 3.2154
# Epoch 25/300
# 6/6 [==============================] - 0s 10ms/step - loss: 18.9921 - mae: 3.3386 - val_loss: 16.2933 - val_mae: 3.1890
# Epoch 26/300
# 6/6 [==============================] - 0s 10ms/step - loss: 19.0481 - mae: 3.3763 - val_loss: 16.6257 - val_mae: 3.2304
# Epoch 27/300
# 6/6 [==============================] - 0s 10ms/step - loss: 18.6346 - mae: 3.3079 - val_loss: 16.2079 - val_mae: 3.1189
# Epoch 28/300
# 6/6 [==============================] - 0s 10ms/step - loss: 18.6875 - mae: 3.2702 - val_loss: 16.3695 - val_mae: 3.1566
# Epoch 29/300
# 6/6 [==============================] - 0s 11ms/step - loss: 18.9719 - mae: 3.3707 - val_loss: 17.1663 - val_mae: 3.2908
# Epoch 30/300
# 6/6 [==============================] - 0s 10ms/step - loss: 18.5268 - mae: 3.2735 - val_loss: 16.2191 - val_mae: 3.0500

# %%
#check the model performace in test dataset
score = model.evaluate(X_test, y_test, verbose=1)
print('loss value: ', score[0])
print('Mean absolute error: ', score[1])
# Out:
# 2/2 [==============================] - 0s 4ms/step - loss: 16.4019 - mae: 2.9541
# loss value:  16.40192413330078
# Mean absolute error:  2.954073190689087

# %%
# predict house price using the test data 
test_predictions = model.predict(X_test).flatten()
print(test_predictions)
# Out:
# 2/2 [==============================] - 0s 4ms/step
# [19.119413 23.142546 21.05366  18.820925 19.181114 22.695818 16.86096
#  22.166628 22.176113 23.229015 18.743105 21.945423 22.946089 21.623243
#  21.033491 22.691187 22.29809  22.52173  20.696486 19.230936 20.101671
#  21.43239  20.094572 22.305035 22.510862 22.839556 20.817806 23.844093
#  22.642534 19.415447 23.914991 22.712149 21.905016 17.012144 21.379972
#  20.562412 18.93921  21.185863 23.52703  18.740103 20.753119 19.441841
#  21.34767  16.963755 21.659231 20.148542 21.811447 21.912756 20.568172
#  22.264872 16.797144 16.940765 22.614805 17.176226]

# %%
# show the true value and predicted value in dataframe
true_predicted = pd.DataFrame(list(zip(y_test, test_predictions)), columns=['True Value','Predicted Value'])
true_predicted.head(10)
# Out:
#    True Value  Predicted Value
# 0        23.0        19.119413
# 1        18.7        23.142546
# 2        14.5        21.053659
# 3        19.1        18.820925
# 4        18.1        19.181114
# 5        23.3        22.695818
# 6        17.7        16.860960
# 7        23.2        22.166628
# 8        18.9        22.176113
# 9        28.0        23.229015

# %%
# visualize the prediction uisng diagonal line
y = test_predictions #y-axis
x = y_test #x-axis
fig, ax = plt.subplots(figsize=(10,6)) # create figure
ax.scatter(x,y) #scatter plots for x,y
ax.set(xlim=(0,55), ylim=(0, 55)) #set limit
ax.plot(ax.get_xlim(), ax.get_ylim(), color ='red') # draw 45 degree diagonal in figure
plt.xlabel('True Values')
plt.ylabel('Predicted values')
plt.title('Evaluation Result')
plt.show()
